# %% [markdown]
# # Sales Forecasting – EDA & Baseline Models
#
# This notebook walks through quick EDA and baseline forecasting approaches (moving average, ARIMA).

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

data_dir = Path('../data')
csv_candidates = list(data_dir.glob('*.csv'))
csv_candidates
